# %%
import sys
sys.path.append("/home/thachbui/workstation/fn3/python_shared_lib/lib/")
from date_ext import now, get_tz

# %%
from datetime import timedelta

tz = get_tz(timedelta(hours=-3, minutes=-51))

# %%
tz
# Out:
# psycopg2.tz.FixedOffsetTimezone(offset=-180, name=None)

# %%
now(tz)
# Out:
# datetime.datetime(2017, 2, 2, 11, 4, 53, 143329, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-231, name=None))

# %%
now(tz).isoformat()
# Out:
# '2017-02-02T11:04:54.020096-03:51'

# %%
longitude = -99.0216642369
latitude = 40.7899645884

min_temperature = 23.0
max_temperature = 36.0
average_temperature = 27.8333

min_dew_point = 12.0
max_dew_point = 27.0
average_dew_point = 18.616

min_humidity = 54.0
max_humidity = 80.0
average_humidity = 68.566

min_rainfall = 0.0
max_railfall = 0.0
average_rainfall = 0.0

# uom = w/m2
min_solar_radiation = 0.0
max_solar_radiation = 161.0
average_solar_radiation = 72.56

#uom = mph
min_wind_speed = 8.0
max_wind_speed = 17.0
average_wind_speed = 13.95

# %%
359.0 /15
# Out:
# 23.933333333333334

# %%
round(359.0 /15)
# Out:
# 24.0

# %%
def central_longitude(longitude):
    
    if longitude > 180 or longitude < -180:
        raise ValueError("longitude only between -180 and 180")
    
    if longitude <= 0:
        longwest = abs(longitude)
    else:
        longwest = 360 - longitude
    
    mult = round(float(longwest)/ 15, 0)

    return (15 * mult) % 360

# %%
def

# %%
longitude
# Out:
# -99.0216642369

# %%
central_longitude(longitude)
# Out:
# 105.0

# %%
central_longitude(-180)
# Out:
# 180.0

# %%
360-29.2
# Out:
# 330.8

# %%
math.ceil(-99.4)
# Out:
# -99.0

# %%
def datetime_range(from_date, to_date, interval=timedelta(days=1)):
    if not isinstance(from_date, datetime):
        raise TypeError("from_date argument must be a datetime, not {0}".format(type(from_date)))
    if not isinstance(to_date, datetime):
        raise TypeError("to_date argument must be a datetime, not {0}".format(type(to_date)))
    if not isinstance(interval, timedelta):
        raise TypeError("interval argument must be a timedelta, not {0}".format(type(interval)))
    if interval == timedelta(0):
        raise ValueError("interval must not be 0")
    if to_date <= from_date:
        if interval > timedelta():
            raise StopIteration
        while from_date > to_date:
            yield from_date
            from_date = from_date + interval
    if to_date > from_date:
        if interval < timedelta():
            raise StopIteration
        while from_date < to_date:
            yield from_date
            from_date = from_date + interval

# %%
from datetime import datetime

# %%
start = datetime(2016, 1, 1)
end = datetime.now()

# %%
for i, date in enumerate (datetime_range(start, end)):
    print i, date
# Out:
# 0 2016-01-01 00:00:00
# 1 2016-01-02 00:00:00
# 2 2016-01-03 00:00:00
# 3 2016-01-04 00:00:00
# 4 2016-01-05 00:00:00
# 5 2016-01-06 00:00:00
# 6 2016-01-07 00:00:00
# 7 2016-01-08 00:00:00
# 8 2016-01-09 00:00:00
# 9 2016-01-10 00:00:00
# 10 2016-01-11 00:00:00
# 11 2016-01-12 00:00:00
# 12 2016-01-13 00:00:00
# 13 2016-01-14 00:00:00
# 14 2016-01-15 00:00:00
# 15 2016-01-16 00:00:00
# 16 2016-01-17 00:00:00
# 17 2016-01-18 00:00:00
# 18 2016-01-19 00:00:00
# 19 2016-01-20 00:00:00
# 20 2016-01-21 00:00:00
