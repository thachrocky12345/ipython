# %%
# !git add -A

# %%
# !git commit -a -m "adding cassandra script"
# Out:
# [master a01cf9e] adding cassandra script
#  2 files changed, 8 insertions(+), 16 deletions(-)
# WARNING:cassandra.cluster:Host 192.168.1.150 has been marked down
# WARNING:cassandra.cluster:Host 192.168.1.221 has been marked down

# %%
# !git push origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 8 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 5.37 KiB | 0 bytes/s, done.
# Total 5 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:thachrocky12345/ipython.git
#    5b8f7a5..94dbc45  master -> master

# %%
from etl.pgdb import PgsqlExecutor
from etl import cassdb

# %%
weather_database =  dict(host='localhost',port=5432, database='decoded', user='thachbui', password='thach12345')
db = PgsqlExecutor(weather_database)

# %%
get_weather_tables = '''
SELECT c.relname weather_table
    FROM pg_catalog.pg_class c
	LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
	WHERE n.nspname = 'weather'
	AND c.relname like 'weather_2%' order by 1 desc
'''

# %%
weather_tables = db.fetch_all_rows(get_weather_tables).query_data

# %%
for i in weather_tables[0:5]:
    print i
# Out:
# Record(weather_table='weather_20170213')
# Record(weather_table='weather_20170212')
# Record(weather_table='weather_20170211')
# Record(weather_table='weather_20170210')
# Record(weather_table='weather_20170209')

# %% [markdown]
# # treaming data and insert

# %%
auth_provider = dict(username='thachbui',
                     password='thach12345',
                     hosts=['192.168.1.150', '192.168.1.221'],
                     port=None,
                     database='weather')

# %%
db_cass = cassdb.CasExecutor(auth_provider)
prepare = cassdb.Prepare(db_cass.cursor, insert_into_cassandra)

# %%
from datetime import datetime
for weather_table in weather_tables:
    count = 0
    weather_table =  weather_table.weather_table
    if weather_table >= 'weather_20170301' or weather_table <= 'weather_20161009' :
#         print weather_table
        continue
    print weather_table
    get_data_from_table = get_data_from_table.format(table=weather_table)
    print get_data_from_table
    db = PgsqlExecutor(weather_database)
    insert_data = db.streaming_cursor(get_data_from_table)
    
    start_time = datetime.now()
    with db_cass.cursor as cursor:
        prepare = cassdb.Prepare(cursor, insert_into_cassandra)
        for row in insert_data:
            count += 1
            prepare.insert_row(row)
    
    print "Run time: {} - total rows: {} ".format(datetime.now() - start_time, count)
# Out:
# weather_20170213
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:24.705645 - total rows: 46264
# weather_20170212
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:18.873499 - total rows: 46264
# weather_20170211
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:16.193210 - total rows: 46264
# weather_20170210
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:19.818803 - total rows: 46264
# weather_20170209
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:18.850679 - total rows: 46264
# weather_20170208
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:17.770368 - total rows: 46264
# weather_20170207
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:23.553499 - total rows: 46264
# weather_20170206
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:17.204625 - total rows: 46264
# weather_20170205
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:41.543458 - total rows: 46264
# weather_20170204
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:41.024489 - total rows: 46264
# weather_20170203
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:43.196756 - total rows: 46264
# weather_20170202
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:45.353361 - total rows: 46264
# weather_20170201
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:03:17.550908 - total rows: 46264
# weather_20170131
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:03:03.270844 - total rows: 46264
# weather_20170130
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:03:06.078132 - total rows: 46264
# weather_20170129
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:52.667367 - total rows: 46264
# weather_20170128
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:03:00.373450 - total rows: 46264
# weather_20170127
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:03:11.390268 - total rows: 46264
# weather_20170126
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:52.426388 - total rows: 46264
# weather_20170125
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:03:14.313428 - total rows: 46264
# weather_20170124
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:03:28.197370 - total rows: 46264
# weather_20170123
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:03:04.175570 - total rows: 46264
# weather_20170122
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:48.916457 - total rows: 46264
# weather_20170121
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:52.287618 - total rows: 46264
# weather_20170120
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:49.136987 - total rows: 46264
# weather_20170119
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:50.721515 - total rows: 46264
# weather_20170118
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:44.824579 - total rows: 46264
# weather_20170117
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:46.805930 - total rows: 46264
# weather_20170115
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:22.842027 - total rows: 46264
# weather_20170103
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:26.005186 - total rows: 46264
# weather_20170102
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:18.723119 - total rows: 46264
# weather_20170101
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:14.236329 - total rows: 46264
# weather_20161231
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:17.859864 - total rows: 46264
# weather_20161230
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:16.949445 - total rows: 46264
# weather_20161229
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:19.036750 - total rows: 46264
# weather_20161228
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:19.021188 - total rows: 46264
# weather_20161227
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:17.727853 - total rows: 46264
# weather_20161226
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:17.375951 - total rows: 46264
# weather_20161225
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:15.659716 - total rows: 46264
# weather_20161224
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:15.346789 - total rows: 46264
# weather_20161223
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:17.160804 - total rows: 46264
# weather_20161222
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:19.547509 - total rows: 46264
# weather_20161221
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:16.177145 - total rows: 46264
# weather_20161220
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:20.927054 - total rows: 46264
# weather_20161219
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:15.350578 - total rows: 46264
# weather_20161218
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
#
# Run time: 0:02:17.096974 - total rows: 46264
# weather_20161217
#
# select
#     countyid ,
#     ts ,
#     weather ,
#     current_temp ,
#     high ,
#     low ,
#     precipitation_am ,
#     precipitation_pm ,
#     dew_point ,
#     wind_gust ,
#     humidity_relh ,
#     slp ,
#     elevation ,
#     windchill ,
#     wind_degree ,
#     wind_speed ,
#     wind_direction
# from weather.weather_20170213 order by ts desc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f8977606fb11> in <module>()
#      17         for row in insert_data:
#      18             count += 1
# ---> 19             prepare.insert_row(row)
#      20
#      21     print "Run time: {} - total rows: {} ".format(datetime.now() - start_time, count)
#
# /opt/sources/etl/cassdb.pyc in insert_row(self, row)
#     233
#     234     def insert_row(self, row):
# --> 235         self.cursor.execute(self.prepare_statement, row)
#     236
#     237     def insert_rows(self, rows):
#
# /opt/sources/cassandra/cluster.so in cassandra.cluster.Session.execute (cassandra/cluster.c:35058)()
#
# /opt/sources/cassandra/cluster.so in cassandra.cluster.ResponseFuture.result (cassandra/cluster.c:73374)()
#
# /usr/lib/python2.7/threading.pyc in wait(self, timeout)
#     612         with self.__cond:
#     613             if not self.__flag:
# --> 614                 self.__cond.wait(timeout)
#     615             return self.__flag
#     616
#
# /usr/lib/python2.7/threading.pyc in wait(self, timeout)
#     338         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     339             if timeout is None:
# --> 340                 waiter.acquire()
#     341                 if __debug__:
#     342                     self._note("%s.wait(): got it", self)
#
# KeyboardInterrupt:
# WARNING:cassandra.cluster:Host 192.168.1.150 has been marked down
# WARNING:cassandra.cluster:Host 192.168.1.221 has been marked down

# %%
print (float(62216)/ 200)
# Out:
# 311.08

# %%
db_cass.close()

# %%
# print prepare.prepare_statement_sql(insert_into_cassandra)

# %%
sql = '''select 
    countyid ,
    ts ,
    weather ,
    current_temp ,
    high ,
    low ,
    precipitation_am ,
    precipitation_pm ,
    dew_point ,
    wind_gust ,
    humidity_relh ,
    slp ,
    elevation ,
    windchill ,
    wind_degree ,
    wind_speed ,
    wind_direction
from weather.weather limit 2000 '''
insert_data = db.streaming_cursor(sql)
from datetime import datetime
start_time = datetime.now()
for row in insert_data:
    prepare.insert_row(row)
print "Run time: {}".format(datetime.now() - start_time)
# Out:
# Run time: 0:00:07.306454

# %%
data = db.fetch_one_row("select * from weather.weather limit 1")
for i in data.query_data._asdict().keys():
    print  "%s,"
# Out:
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,

# %%
get_data_from_table = '''
select 
    countyid ,
    ts ,
    weather ,
    current_temp ,
    high ,
    low ,
    precipitation_am ,
    precipitation_pm ,
    dew_point ,
    wind_gust ,
    humidity_relh ,
    slp ,
    elevation ,
    windchill ,
    wind_degree ,
    wind_speed ,
    wind_direction
from weather.{table} order by ts desc
'''

# %%
insert_into_cassandra = '''
insert into weather (
countyid ,
    ts ,
    weather ,
    current_temp ,
    high ,
    low ,
    precipitation_am ,
    precipitation_pm ,
    dew_point ,
    wind_gust ,
    humidity_relh ,
    slp ,
    elevation ,
    windchill ,
    wind_degree ,
    wind_speed ,
    wind_direction
    )
    
values (

# %s,%s,%s,%s,%s,
# %s,%s,%s,%s,
# %s,%s,%s,%s,
# %s,%s,%s,%s
)
'''

# %%
import sys
sys.path.append("/home/thachbui/workstation/cass_scripts/copy/")
from cass_async_copy import MultiProcessCopy, Copy
